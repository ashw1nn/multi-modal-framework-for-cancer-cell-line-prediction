# %%
import torch
torch.cuda.empty_cache()
from rdkit import Chem
from rdkit.Chem import AllChem
import pandas as pd
import numpy as np
import os


ablation_study_id = 1
os.chdir('../')

# %%
gdsc_df = pd.read_csv("dataset/GDSC_SMILES_merged.csv", index_col=0)
gdsc_df
# Out:
#         DRUG_ID          DRUG_NAME CELL_LINE_NAME    LN_IC50  \
# 0          1003       Camptothecin         PFSK-1  -1.462148
# 1          1003       Camptothecin           A673  -4.869447
# 2          1003       Camptothecin            ES5  -3.360684
# 3          1003       Camptothecin            ES7  -5.045014
# 4          1003       Camptothecin          EW-11  -3.741620
# ...         ...                ...            ...        ...
# 242031     2499  N-acetyl cysteine        SNU-175  10.134495
# 242032     2499  N-acetyl cysteine        SNU-407   8.575555
# 242033     2499  N-acetyl cysteine         SNU-61  10.520666
# 242034     2499  N-acetyl cysteine         SNU-C5  10.701430
# 242035     2499  N-acetyl cysteine           DiFi  10.038769
#
#                                                    SMILES
# 0       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...
# 1       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...
# 2       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...
# 3       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...
# 4       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...
# ...                                                   ...
# 242031                                 CC(=O)NC(CS)C(=O)O
# 242032                                 CC(=O)NC(CS)C(=O)O
# 242033                                 CC(=O)NC(CS)C(=O)O
# 242034                                 CC(=O)NC(CS)C(=O)O
# 242035                                 CC(=O)NC(CS)C(=O)O
#
# [199501 rows x 5 columns]

# %%
ccl_rep_df = pd.read_csv("dataset/PANCANCER_Genetic_feature.csv")

# Pivot to get binary matrix: rows = cell lines, columns = features
binary_feature_matrix = ccl_rep_df.pivot_table(
    index="cell_line_name",
    columns="genetic_feature",
    values="is_mutated",
    fill_value=0
).astype(int)

# %%
binary_feature_matrix.columns = binary_feature_matrix.columns.astype(str)

# %%
binary_feature_matrix
# Out:
# genetic_feature  ABCB1_mut  ABL2_mut  ACACA_mut  ACVR1B_mut  ACVR2A_mut  \
# cell_line_name
# 201T                     0         0          0           0           0
# 22RV1                    0         0          0           0           0
# 23132-87                 0         0          0           0           0
# 42-MG-BA                 0         0          0           0           0
# 451Lu                    0         0          0           0           0
# ...                    ...       ...        ...         ...         ...
# YT                       0         0          0           0           0
# ZR-75-30                 0         0          0           0           0
# huH-1                    0         0          0           0           0
# no-10                    0         0          0           0           0
# no-11                    0         0          0           0           0
#
# genetic_feature  ADCY1_mut  AFF4_mut  AHCTF1_mut  AHNAK_mut  AKAP9_mut  ...  \
# cell_line_name                                                          ...
# 201T                     0         0           0          0          0  ...
# 22RV1                    0         0           0          0          0  ...
# 23132-87                 0         0           0          0          0  ...
# 42-MG-BA                 0         0           0          0          0  ...
# 451Lu                    0         0           0          0          0  ...
# ...                    ...       ...         ...        ...        ...  ...
# YT                       0         0           0          0          0  ...
# ZR-75-30                 0         0           0          0          0  ...
# huH-1                    0         0           0          0          0  ...
# no-10                    0         0           0          0          0  ...
# no-11                    0         0           0          0          0  ...
#
# genetic_feature  cnaPANCAN90  cnaPANCAN91  cnaPANCAN92  cnaPANCAN93  \
# cell_line_name
# 201T                       0            1            0            0
# 22RV1                      0            0            0            0
# 23132-87                   0            0            0            0
# 42-MG-BA                   0            0            0            0
# 451Lu                      1            1            1            0
# ...                      ...          ...          ...          ...
# YT                         0            0            0            0
# ZR-75-30                   1            1            1            0
# huH-1                      0            0            1            0
# no-10                      0            0            0            0
# no-11                      0            0            1            0
#
# genetic_feature  cnaPANCAN94  cnaPANCAN95  cnaPANCAN96  cnaPANCAN97  \
# cell_line_name
# 201T                       0            0            0            0
# 22RV1                      0            0            0            0
# 23132-87                   0            0            0            0
# 42-MG-BA                   0            0            0            0
# 451Lu                      0            0            0            0
# ...                      ...          ...          ...          ...
# YT                         0            0            0            0
# ZR-75-30                   0            0            0            0
# huH-1                      0            0            0            1
# no-10                      0            0            0            0
# no-11                      0            0            0            0
#
# genetic_feature  cnaPANCAN98  cnaPANCAN99
# cell_line_name
# 201T                       0            0
# 22RV1                      0            0
# 23132-87                   0            0
# 42-MG-BA                   0            0
# 451Lu                      0            0
# ...                      ...          ...
# YT                         0            0
# ZR-75-30                   0            0
# huH-1                      1            0
# no-10                      0            0
# no-11                      0            0
#
# [990 rows x 735 columns]

# %%
binary_feature_matrix.index = binary_feature_matrix.index.str.upper()

# %%
import re

def clean_name(name):
    return re.sub(r'[^A-Za-z0-9]', '', name).upper()

# %% [markdown]
# ### CCL embeddings

# %%
binary_feature_matrix.index = binary_feature_matrix.index.to_series().apply(clean_name)
binary_feature_matrix
# Out:
# genetic_feature  ABCB1_mut  ABL2_mut  ACACA_mut  ACVR1B_mut  ACVR2A_mut  \
# cell_line_name
# 201T                     0         0          0           0           0
# 22RV1                    0         0          0           0           0
# 2313287                  0         0          0           0           0
# 42MGBA                   0         0          0           0           0
# 451LU                    0         0          0           0           0
# ...                    ...       ...        ...         ...         ...
# YT                       0         0          0           0           0
# ZR7530                   0         0          0           0           0
# HUH1                     0         0          0           0           0
# NO10                     0         0          0           0           0
# NO11                     0         0          0           0           0
#
# genetic_feature  ADCY1_mut  AFF4_mut  AHCTF1_mut  AHNAK_mut  AKAP9_mut  ...  \
# cell_line_name                                                          ...
# 201T                     0         0           0          0          0  ...
# 22RV1                    0         0           0          0          0  ...
# 2313287                  0         0           0          0          0  ...
# 42MGBA                   0         0           0          0          0  ...
# 451LU                    0         0           0          0          0  ...
# ...                    ...       ...         ...        ...        ...  ...
# YT                       0         0           0          0          0  ...
# ZR7530                   0         0           0          0          0  ...
# HUH1                     0         0           0          0          0  ...
# NO10                     0         0           0          0          0  ...
# NO11                     0         0           0          0          0  ...
#
# genetic_feature  cnaPANCAN90  cnaPANCAN91  cnaPANCAN92  cnaPANCAN93  \
# cell_line_name
# 201T                       0            1            0            0
# 22RV1                      0            0            0            0
# 2313287                    0            0            0            0
# 42MGBA                     0            0            0            0
# 451LU                      1            1            1            0
# ...                      ...          ...          ...          ...
# YT                         0            0            0            0
# ZR7530                     1            1            1            0
# HUH1                       0            0            1            0
# NO10                       0            0            0            0
# NO11                       0            0            1            0
#
# genetic_feature  cnaPANCAN94  cnaPANCAN95  cnaPANCAN96  cnaPANCAN97  \
# cell_line_name
# 201T                       0            0            0            0
# 22RV1                      0            0            0            0
# 2313287                    0            0            0            0
# 42MGBA                     0            0            0            0
# 451LU                      0            0            0            0
# ...                      ...          ...          ...          ...
# YT                         0            0            0            0
# ZR7530                     0            0            0            0
# HUH1                       0            0            0            1
# NO10                       0            0            0            0
# NO11                       0            0            0            0
#
# genetic_feature  cnaPANCAN98  cnaPANCAN99
# cell_line_name
# 201T                       0            0
# 22RV1                      0            0
# 2313287                    0            0
# 42MGBA                     0            0
# 451LU                      0            0
# ...                      ...          ...
# YT                         0            0
# ZR7530                     0            0
# HUH1                       1            0
# NO10                       0            0
# NO11                       0            0
#
# [990 rows x 735 columns]

# %% [markdown]
# ### Drugs

# %%
gdsc_df["CLEAN_CELL_LINE"] = gdsc_df["CELL_LINE_NAME"].apply(clean_name)
gdsc_df
# Out:
#         DRUG_ID          DRUG_NAME CELL_LINE_NAME    LN_IC50  \
# 0          1003       Camptothecin         PFSK-1  -1.462148
# 1          1003       Camptothecin           A673  -4.869447
# 2          1003       Camptothecin            ES5  -3.360684
# 3          1003       Camptothecin            ES7  -5.045014
# 4          1003       Camptothecin          EW-11  -3.741620
# ...         ...                ...            ...        ...
# 242031     2499  N-acetyl cysteine        SNU-175  10.134495
# 242032     2499  N-acetyl cysteine        SNU-407   8.575555
# 242033     2499  N-acetyl cysteine         SNU-61  10.520666
# 242034     2499  N-acetyl cysteine         SNU-C5  10.701430
# 242035     2499  N-acetyl cysteine           DiFi  10.038769
#
#                                                    SMILES CLEAN_CELL_LINE
# 0       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...           PFSK1
# 1       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...            A673
# 2       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...             ES5
# 3       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...             ES7
# 4       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...            EW11
# ...                                                   ...             ...
# 242031                                 CC(=O)NC(CS)C(=O)O          SNU175
# 242032                                 CC(=O)NC(CS)C(=O)O          SNU407
# 242033                                 CC(=O)NC(CS)C(=O)O           SNU61
# 242034                                 CC(=O)NC(CS)C(=O)O           SNUC5
# 242035                                 CC(=O)NC(CS)C(=O)O            DIFI
#
# [199501 rows x 6 columns]

# %% [markdown]
# ### Fingerprints

# %%
def compute_morgan(smiles, radius=2, n_bits=2048):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return [0] * n_bits
    fp = AllChem.GetMorganFingerprintAsBitVect(mol, radius, nBits=n_bits)
    return list(fp)

# %%
unique_drugs = gdsc_df[["DRUG_ID", "SMILES"]].drop_duplicates().reset_index(drop=True)
unique_drugs["FINGERPRINT"] = unique_drugs["SMILES"].apply(compute_morgan)
fingerprint_dict = dict(zip(unique_drugs["DRUG_ID"], unique_drugs["FINGERPRINT"]))
# Out:
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator
# [21:17:14] DEPRECATION WARNING: please use MorganGenerator

# %% [markdown]
# ### GSVA scores

# %%
gsva_df = pd.read_csv("dataset/ccle_gsva_scores.csv", index_col=0)
gsva_df
# Out:
#                                                     X22RV1_PROSTATE  \
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA...         0.244789
# KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_...         0.232631
# KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS                -0.186705
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED...        -0.540508
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING...        -0.166025
# ...                                                             ...
# KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC...        -0.117058
# KEGG_MEDICUS_VARIANT_TEL_AML1_FUSION_TO_TRANSCR...        -0.071946
# KEGG_MEDICUS_VARIANT_TGFA_OVEREXPRESSION_TO_PI3...        -0.288375
# KEGG_MEDICUS_VARIANT_TMPRSS2_ERG_FUSION_TO_TRAN...        -0.566128
# KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E...         0.277608
#
#                                                     X2313287_STOMACH  \
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA
# KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E...                        -0.368974
#
#                                                     YD15_SALIVARY_GLAND  \
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA...            -0.355703
# KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_...             0.211546
# KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS                    -0.116195
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED...             0.457628
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING...             0.156438
# ...                                                                 ...
# KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC...             0.157373
# KEGG_MEDICUS_VARIANT_TEL_AML1_FUSION_TO_TRANSCR...             0.325866
# KEGG_MEDICUS_VARIANT_TGFA_OVEREXPRESSION_TO_PI3...             0.208207
# KEGG_MEDICUS_VARIANT_TMPRSS2_ERG_FUSION_TO_TRAN...             0.366406
# KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E...            -0.049374
#
#                                                     YD38_UPPER_AERODIGESTIVE_TRACT  \
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA...                       -0.101719
# KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_...                       -0.032558
# KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS                               -0.179142
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED...                        0.006197
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING...                       -0.064297
# ...                                                                            ...
# KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC...                        0.250761
# KEGG_MEDICUS_VARIANT_TEL_AML1_FUSION_TO_TRANSCR...                        0.628831
# KEGG_MEDICUS_VARIANT_TGFA_OVEREXPRESSION_TO_PI3...                        0.303945
# KEGG_MEDICUS_VARIANT_TMPRSS2_ERG_FUSION_TO_TRAN...                        0.542634
# KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E...                       -0.165126
#
#                                                     YD8_UPPER_AERODIGESTIVE_TRACT  \
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA...                      -0.530021
# KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_...                       0.151900
# KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS                               0.231483
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED...                      -0.417248
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING...                       0.338911
# ...                                                                           ...
# KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC...                      -0.209867
# KEGG_MEDICUS_VARIANT_TEL_AML1_FUSION_TO_TRANSCR...                       0.454693
# KEGG_MEDICUS_VARIANT_TGFA_OVEREXPRESSION_TO_PI3...                       0.378906
# KEGG_MEDICUS_VARIANT_TMPRSS2_ERG_FUSION_TO_TRAN...                      -0.223423
# KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E...                       0.205630
#
#                                                     YH13_CENTRAL_NERVOUS_SYSTEM  \
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA...                    -0.537348
# KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_...                     0.317689
# KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS                             0.155220
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED...                    -0.453304
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING...                     0.224560
# ...                                                                         ...
# KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC...                     0.035322
# KEGG_MEDICUS_VARIANT_TEL_AML1_FUSION_TO_TRANSCR...                     0.169221
# KEGG_MEDICUS_VARIANT_TGFA_OVEREXPRESSION_TO_PI3...                     0.233616
# KEGG_MEDICUS_VARIANT_TMPRSS2_ERG_FUSION_TO_TRAN...                     0.224992
# KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E...                     0.199840
#
#                                                     YKG1_CENTRAL_NERVOUS_SYSTEM  \
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA...                     0.275503
# KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_...                    -0.332108
# KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS                             0.205721
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED...                    -0.136213
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING...                     0.143953
# ...                                                                         ...
# KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC...                     0.055748
# KEGG_MEDICUS_VARIANT_TEL_AML1_FUSION_TO_TRANSCR...                     0.040660
# KEGG_MEDICUS_VARIANT_TGFA_OVEREXPRESSION_TO_PI3...                     0.152003
# KEGG_MEDICUS_VARIANT_TMPRSS2_ERG_FUSION_TO_TRAN...                     0.234498
# KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E...                     0.089472
#
#                                                     ZR751_BREAST  \
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA...      0.526732
# KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_...     -0.430653
# KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS             -0.166378
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED...      0.387118
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING...      0.002501
# ...                                                          ...
# KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC...      0.194295
# KEGG_MEDICUS_VARIANT_TEL_AML1_FUSION_TO_TRANSCR...     -0.249230
# KEGG_MEDICUS_VARIANT_TGFA_OVEREXPRESSION_TO_PI3...     -0.139507
# KEGG_MEDICUS_VARIANT_TMPRSS2_ERG_FUSION_TO_TRAN...     -0.452274
# KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E...     -0.244789
#
#                                                     ZR7530_BREAST
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA...       0.220102
# KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_...       0.182114
# KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS               0.045039
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED...       0.503203
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING...       0.102778
# ...                                                           ...
# KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC...       0.100961
# KEGG_MEDICUS_VARIANT_TEL_AML1_FUSION_TO_TRANSCR...      -0.453372
# KEGG_MEDICUS_VARIANT_TGFA_OVEREXPRESSION_TO_PI3...      -0.157565
# KEGG_MEDICUS_VARIANT_TMPRSS2_ERG_FUSION_TO_TRAN...      -0.463809
# KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E...      -0.357171
#
# [658 rows x 1019 columns]

# %%
gdsc_df["CELL_LINE_NAME"] = gdsc_df["CELL_LINE_NAME"].str.strip().str.upper()
cell_lines_obs = set(gdsc_df["CELL_LINE_NAME"].unique())

gsva_df.columns = gsva_df.columns.str.strip().str.upper()
cell_lines_available = sorted(set(gsva_df.columns.str.split("_").str[0].str.upper()))

# %%
cell_lines_available = {clean_name(name) for name in cell_lines_available}
cell_lines_obs = {clean_name(name) for name in cell_lines_obs}

# %%
common_cell_lines = cell_lines_obs.intersection(cell_lines_available)
print("Now common cell lines:", len(common_cell_lines))
# Out:
# Now common cell lines: 607

# %%
gsva_df.columns = gsva_df.columns.str.split("_").str[0].str.upper().to_series().apply(clean_name)
gsva_df.columns.has_duplicates
# Out:
# True

# %%
gsva_df = gsva_df.loc[:, ~gsva_df.columns.duplicated()]
print(gsva_df.columns.has_duplicates)
gsva_df
# Out:
# False
#                                                       X22RV1  X2313287  \
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA...  0.244789 -0.083931
# KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_...  0.232631  0.414819
# KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS         -0.186705  0.177009
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED... -0.540508 -0.258760
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING... -0.166025  0.121127
# ...                                                      ...       ...
# KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC... -0.117058  0.534826
# KEGG_MEDICUS_VARIANT_TEL_AML1_FUSION_TO_TRANSCR... -0.071946 -0.235064
# KEGG_MEDICUS_VARIANT_TGFA_OVEREXPRESSION_TO_PI3... -0.288375 -0.230789
# KEGG_MEDICUS_VARIANT_TMPRSS2_ERG_FUSION_TO_TRAN... -0.566128 -0.454890
# KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E...  0.277608  0.081306
#
#                                                      X253JBV     X253J  \
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA...  0.279529  0.208577
# KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_
# KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E... -0.244789 -0.357171
#
# [658 rows x 1018 columns]

# %% [markdown]
# # Creating Dataset

# %%
from rdkit import Chem
import torch
from torch_geometric.data import Data

from torch.utils.data import Dataset

# %%
# Define categorical vocabularies
ATOM_LIST = ['C', 'N', 'O', 'S', 'F', 'P', 'Cl', 'Br', 'I', 'H', 'B', 'Si', 'Na', 'K', 'Li', 'Mg', 'Ca', 'Fe', 'Zn', 'Se', 'Cu']
DEGREE_LIST = list(range(0, 11))
VALENCE_LIST = list(range(0, 7))
HYBRIDIZATION_LIST = [
    Chem.rdchem.HybridizationType.SP, Chem.rdchem.HybridizationType.SP2,
    Chem.rdchem.HybridizationType.SP3, Chem.rdchem.HybridizationType.SP3D,
    Chem.rdchem.HybridizationType.SP3D2
]
TOTAL_H_LIST = [0, 1, 2, 3, 4]
CHIRALITY_LIST = ['R', 'S']

# %%
def one_hot_encoding(x, allowable):
    return [int(x == s) for s in allowable]

# %%
def atom_features(atom):
    features = []
    features += one_hot_encoding(atom.GetSymbol(), ATOM_LIST)
    features += one_hot_encoding(atom.GetDegree(), DEGREE_LIST)
    features += one_hot_encoding(atom.GetImplicitValence(), VALENCE_LIST)
    features.append(atom.GetFormalCharge())
    features.append(atom.GetNumRadicalElectrons())
    features += one_hot_encoding(atom.GetHybridization(), HYBRIDIZATION_LIST)
    features.append(int(atom.GetIsAromatic()))
    features += one_hot_encoding(atom.GetTotalNumHs(), TOTAL_H_LIST)
    features.append(int(atom.IsInRing()))
    
    chirality = atom.GetProp('_CIPCode') if atom.HasProp('_CIPCode') else None
    features += one_hot_encoding(chirality, CHIRALITY_LIST)
    
    return features

# %%
def smiles_to_graph(smiles):
    mol = Chem.MolFromSmiles(smiles)
    if mol is None:
        return None
    
    atom_feats = [atom_features(atom) for atom in mol.GetAtoms()]
    x = torch.tensor(atom_feats, dtype=torch.float)

    edge_index = []
    for bond in mol.GetBonds():
        i = bond.GetBeginAtomIdx()
        j = bond.GetEndAtomIdx()
        edge_index.append((i, j))
        edge_index.append((j, i))  # undirected

    edge_index = torch.tensor(edge_index, dtype=torch.long).t().contiguous()
    
    return Data(x=x, edge_index=edge_index)

# %%
import re
from torch.utils.data import Dataset
import torch

class ModifiedMGATAFDataset(Dataset):
    def __init__(self, gdsc_df, fingerprint_dict, cell_feature_matrix, gsva_matrix, graph_dict):
        self.df = gdsc_df
        self.fingerprint_dict = fingerprint_dict  # drug_id -> np.array or list
        self.cell_features = cell_feature_matrix  # DataFrame: index=cell_line_name, values=mutation+cnv
        self.gsva_matrix = gsva_matrix            # DataFrame: index=cell_line_name, values=gsva scores
        self.graphs = graph_dict                  # drug_id -> graph object (PyG or DGL)

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        drug_id = row["DRUG_ID"]
        cell_line = row["CLEAN_CELL_LINE"]

        # Drug molecular graph
        graph_data = self.graphs[drug_id]

        # Fingerprint vector
        fingerprint = torch.tensor(self.fingerprint_dict[drug_id], dtype=torch.float)

        # Cell line mutation/CNV features
        ccl_feat = torch.tensor(self.cell_features.loc[cell_line].values, dtype=torch.float)

        # GSVA pathway scores
        if cell_line not in self.gsva_matrix.index:
            raise ValueError(f"{cell_line} not found in GSVA matrix.")
        gsva_feat = torch.tensor(self.gsva_matrix.loc[cell_line].values, dtype=torch.float)

        # Target IC50
        ic50 = torch.tensor([row["LN_IC50"]], dtype=torch.float)

        return graph_data, fingerprint, ccl_feat, gsva_feat, ic50

# %%
# Step 1: Clean the GDSC cell line column
# gdsc_df["CELL_LINE_NAME_CLEAN"] = gdsc_df["CELL_LINE_NAME"].apply(clean_name)

# Step 2: Clean the index of the binary feature matrix
binary_feature_matrix.index = binary_feature_matrix.index.to_series().apply(clean_name)
binary_feature_matrix = binary_feature_matrix[~binary_feature_matrix.index.duplicated(keep='first')]

# Step 3: Clean GSVA matrix columns
gsva_df.columns = gsva_df.columns.to_series().apply(clean_name)
gsva_df = gsva_df.loc[:, ~gsva_df.columns.duplicated(keep='first')]

# Step 4: Determine valid IDs
valid_drugs = set(fingerprint_dict.keys())
valid_mutcnv_cells = set(binary_feature_matrix.index)
valid_gsva_cells = set(gsva_df.columns)

# Step 5: Get cell lines common to all three
common_cell_lines = valid_mutcnv_cells & valid_gsva_cells & set(gdsc_df["CLEAN_CELL_LINE"])
common_cell_lines = list(common_cell_lines)
# Step 6: Filter gdsc_df to keep only rows with common cell lines and valid drugs/SMILES
gdsc_df = gdsc_df[
    gdsc_df["DRUG_ID"].isin(valid_drugs) &
    gdsc_df["CLEAN_CELL_LINE"].isin(common_cell_lines) &
    gdsc_df["SMILES"].notna()
].reset_index(drop=True)

# Step 7: Filter binary_feature_matrix and gsva_matrix to keep only common cell lines
binary_feature_matrix = binary_feature_matrix.loc[common_cell_lines]
gsva_df = gsva_df.loc[:, list(common_cell_lines)]  # since cell lines are columns

# Normalise the ln IC50 values
gdsc_df['LN_IC50'] = 1 / (np.exp(-0.1 * gdsc_df['LN_IC50']) + 1)

# %%
gdsc_df
# Out:
#         DRUG_ID          DRUG_NAME CELL_LINE_NAME   LN_IC50  \
# 0          1003       Camptothecin           A673  0.380614
# 1          1003       Camptothecin        SK-ES-1  0.374186
# 2          1003       Camptothecin       COLO-829  0.469282
# 3          1003       Camptothecin            RT4  0.426465
# 4          1003       Camptothecin          SW780  0.463887
# ...         ...                ...            ...       ...
# 125091     2499  N-acetyl cysteine           MM1S  0.717484
# 125092     2499  N-acetyl cysteine        SNU-175  0.733695
# 125093     2499  N-acetyl cysteine        SNU-407  0.702150
# 125094     2499  N-acetyl cysteine         SNU-61  0.741172
# 125095     2499  N-acetyl cysteine         SNU-C5  0.744624
#
#                                                    SMILES CLEAN_CELL_LINE
# 0       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...            A673
# 1       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...           SKES1
# 2       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...         COLO829
# 3       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...             RT4
# 4       CCC1(C2=C(COC1=O)C(=O)N3CC4=CC5=CC=CC=C5N=C4C3...           SW780
# ...                                                   ...             ...
# 125091                                 CC(=O)NC(CS)C(=O)O            MM1S
# 125092                                 CC(=O)NC(CS)C(=O)O          SNU175
# 125093                                 CC(=O)NC(CS)C(=O)O          SNU407
# 125094                                 CC(=O)NC(CS)C(=O)O           SNU61
# 125095                                 CC(=O)NC(CS)C(=O)O           SNUC5
#
# [125096 rows x 6 columns]

# %%
binary_feature_matrix
# Out:
# genetic_feature  ABCB1_mut  ABL2_mut  ACACA_mut  ACVR1B_mut  ACVR2A_mut  \
# cell_line_name
# LS123                    0         0          0           0           1
# DANG                     0         0          0           0           0
# NCIH211                  1         0          0           0           0
# NCIH2172                 0         0          0           0           0
# OC314                    0         0          0           0           0
# ...                    ...       ...        ...         ...         ...
# RCHACV                   0         0          0           0           0
# HT1080                   0         0          0           0           0
# NCIH2122                 0         0          0           0           0
# A2058                    0         0          0           0           0
# EN                       1         0          0           1           0
#
# genetic_feature  ADCY1_mut  AFF4_mut  AHCTF1_mut  AHNAK_mut  AKAP9_mut  ...  \
# cell_line_name                                                          ...
# LS123                    0         0           0          0          0  ...
# DANG                     0         0           0          0          0  ...
# NCIH211                  0         0           0          0          0  ...
# NCIH2172                 0         0           1          0          0  ...
# OC314                    0         0           0          0          0  ...
# ...                    ...       ...         ...        ...        ...  ...
# RCHACV                   0         0           0          0          0  ...
# HT1080                   0         0           0          0          0  ...
# NCIH2122                 0         0           0          0          0  ...
# A2058                    0         0           0          0          0  ...
# EN                       0         0           1          0          0  ...
#
# genetic_feature  cnaPANCAN90  cnaPANCAN91  cnaPANCAN92  cnaPANCAN93  \
# cell_line_name
# LS123                      0            0            1            0
# DANG                       0            0            1            0
# NCIH211                    0            0            1            0
# NCIH2172                   0            0            0            0
# OC314                      0            0            0            0
# ...                      ...          ...          ...          ...
# RCHACV                     0            0            0            0
# HT1080                     0            0            0            0
# NCIH2122                   0            1            0            0
# A2058                      0            0            1            0
# EN                         0            0            0            0
#
# genetic_feature  cnaPANCAN94  cnaPANCAN95  cnaPANCAN96  cnaPANCAN97  \
# cell_line_name
# LS123                      0            1            1            0
# DANG                       0            0            0            1
# NCIH211                    0            0            0            1
# NCIH2172                   0            0            0            0
# OC314                      0            0            0            0
# ...                      ...          ...          ...          ...
# RCHACV                     0            0            0            0
# HT1080                     0            0            0            0
# NCIH2122                   0            0            0            0
# A2058                      0            0            0            0
# EN                         0            0            0            0
#
# genetic_feature  cnaPANCAN98  cnaPANCAN99
# cell_line_name
# LS123                      0            0
# DANG                       1            0
# NCIH211                    1            1
# NCIH2172                   0            0
# OC314                      0            0
# ...                      ...          ...
# RCHACV                     0            0
# HT1080                     0            0
# NCIH2122                   0            0
# A2058                      0            1
# EN                         0            0
#
# [601 rows x 735 columns]

# %%
drug_smiles = gdsc_df.drop_duplicates(subset="DRUG_ID")[["DRUG_ID", "SMILES"]]

# %%
precomputed_graphs = {}
for _, row in drug_smiles.iterrows():
    drug_id = row["DRUG_ID"]
    smi = row["SMILES"]
    graph = smiles_to_graph(smi)
    if graph is not None:
        precomputed_graphs[drug_id] = graph

# %%
gsva_df
# Out:
#                                                        LS123      DANG  \
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA... -0.314352 -0.179833
# KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_... -0.141081  0.128651
# KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS          0.171996 -0.062629
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED...  0.345736  0.243901
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING...  0.119669  0.085459
# ...                                                      ...       ...
# KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC...  0.350120 -0.359000
# KEGG_MEDICUS_VARIANT_TEL_AML1_FUSION_TO_TRANSCR...  0.153698  0.214869
# KEGG_MEDICUS_VARIANT_TGFA_OVEREXPRESSION_TO_PI3...  0.325649  0.486002
# KEGG_MEDICUS_VARIANT_TMPRSS2_ERG_FUSION_TO_TRAN...  0.427703  0.280505
# KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E... -0.012462  0.015323
#
#                                                      NCIH211  NCIH2172  \
# KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRA... -0.171423  0.298747
# KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_...  0.008630  0.387324
# KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS         -0.066501  0.230913
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED...  0.311233 -0.371787
# KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING...  0.194450  0.019788
# ...                                                      ...       ...
# KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC
EGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_E...  0.052947 -0.024963
#
# [658 rows x 601 columns]

# %%
gsva_matrix = gsva_df.T  # Now cell lines are rows
gsva_matrix
# Out:
#           KEGG_MEDICUS_ENV_FACTOR_ARSENIC_TO_ELECTRON_TRANSFER_IN_COMPLEX_IV  \
# LS123                                             -0.314352
# DANG                                              -0.179833
# NCIH211                                           -0.171423
# NCIH2172                                           0.298747
# OC314                                              0.187673
# ...                                                     ...
# RCHACV                                             0.499599
# HT1080                                             0.072860
# NCIH2122                                           0.515450
# A2058                                             -0.176043
# EN                                                -0.267539
#
#           KEGG_MEDICUS_ENV_FACTOR_BENZO_A_PYRENRE_TO_CYP_MEDIATED_METABOLISM  \
# LS123                                             -0.141081
# DANG                                               0.128651
# NCIH211                                            0.008630
# NCIH2172                                           0.387324
# OC314                                              0.062629
# ...                                                     ...
# RCHACV                                            -0.330466
# HT1080                                            -0.609524
# NCIH2122                                           0.719678
# A2058                                             -0.607811
# EN                                                -0.208436
#
#           KEGG_MEDICUS_ENV_FACTOR_DCE_TO_DNA_ADDUCTS  \
# LS123                                       0.171996
# DANG                                       -0.062629
# NCIH211                                    -0.066501
# NCIH2172                                    0.230913
# OC314                                      -0.192297
# ...                                              ...
# RCHACV                                     -0.194709
# HT1080                                     -0.225719
# NCIH2122                                    0.685293
# A2058                                      -0.241557
# EN                                          0.182834
#
#           KEGG_MEDICUS_ENV_FACTOR_E2_TO_NUCLEAR_INITIATED_ESTROGEN_SIGNALING_PATHWAY  \
# LS123                                              0.345736
# DANG                                               0.243901
# NCIH211                                            0.311233
# NCIH2172                                          -0.371787
# OC314                                             -0.340220
# ...                                                     ...
# RCHACV                                             0.276438
# HT1080                                            -0.056272
# NCIH2122                                           0.665712
# A2058                                             -0.517250
# EN                                                -0.113090
#
#           KEGG_MEDICUS_ENV_FACTOR_E2_TO_RAS_ERK_SIGNALING_PATHWAY  \
# LS123                                              0.119669
# DANG                                               0.085459
# NCIH211                                            0.194450
# NCIH2172                                           0.019788
# OC314                                             -0.534331
# ...                                                     ...
# RCHACV                                            -0.301077
# HT1080                                             0.240786
# NCIH2122                                          -0.212233
# A2058                                             -0.344284
# EN                                                -0.197986
#
#           KEGG_MEDICUS_ENV_FACTOR_IRON_TO_ANTEROGRADE_AXONAL_TRANSPORT  \
# LS123                                              0.243337
# DANG                                              -0.074537
# NCIH211                                            0.008900
# NCIH2172                                           0.266695
# OC314                                              0.147382
# ...                                                     ...
# RCHACV                                             0.317403
# HT1080                                             0.320138
# NCIH2122                                          -0.584590
# A2058                                              0.113144
# EN                                                 0.364312
#
#           KEGG_MEDICUS_ENV_FACTOR_METALS_TO_JNK_SIGNALING_PATHWAY  \
# LS123                                             -0.015711
# DANG                                               0.186518
# NCIH211                                           -0.297200
# NCIH2172                                           0.328511
# OC314                                             -0.183038
# ...                                                     ...
# RCHACV                                            -0.422647
# HT1080                                            -0.045145
# NCIH2122                                           0.134048
# A2058                                             -0.635966
# EN                                                -0.122994
#
#           KEGG_MEDICUS_ENV_FACTOR_METALS_TO_KEAP1_NRF2_SIGNALIG_PATHWAY  \
# LS123                                             -0.546396
# DANG                                              -0.090961
# NCIH211                                           -0.257182
# NCIH2172                                           0.549831
# OC314                                             -0.442382
# ...                                                     ...
# RCHACV                                            -0.370864
# HT1080                                            -0.424301
# NCIH2122                                           0.675146
# A2058                                             -0.403715
# EN                                                 0.415271
#
#           KEGG_MEDICUS_ENV_FACTOR_METALS_TO_NFKB_SIGNALING_PATHWAY  \
# LS123                                             -0.185794
# DANG                                               0.136693
# NCIH211                                           -0.061855
# NCIH2172                                          -0.124612
# OC314                                             -0.398575
# ...                                                     ...
# RCHACV                                            -0.094663
# HT1080                                             0.224342
# NCIH2122                                          -0.011002
# A2058                                              0.334593
# EN                                                -0.185321
#
#           KEGG_MEDICUS_ENV_FACTOR_METALS_TO_RAS_ERK_SIGNALING_PATHWAY  ...  \
# LS123                                              0.149600            ...
# DANG                                               0.044748            ...
# NCIH211                                            0.137990            ...
# NCIH2172                                           0.203752            ...
# OC314                                             -0.550071            ...
# ...                                                     ...            ...
# RCHACV                                            -0.437480            ...
# HT1080                                             0.185937            ...
# NCIH2122                                          -0.420947            ...
# A2058                                             -0.384885            ...
# EN                                                -0.034492            ...
#
#           KEGG_MEDICUS_VARIANT_RET_FUSION_KINASE_TO_RAS_ERK_SIGNALING_PATHWAY  \
# LS123                                             -0.010649
# DANG                                               0.015640
# NCIH211                                            0.367415
# NCIH2172                                           0.067960
# OC314                                             -0.613578
# ...                                                     ...
# RCHACV                                            -0.144974
# HT1080                                             0.088124
# NCIH2122                                          -0.441630
# A2058                                             -0.216610
# EN                                                 0.083884
#
#           KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC_TO_26S_PROTEASOME_MEDIATED_PROTEIN_DEGRADATION  \
# LS123                                              0.048504
# DANG                                               0.411403
# NCIH211                                            0.432711
# NCIH2172                                           0.499840
# OC314                                             -0.155082
# ...                                                     ...
# RCHACV                                             0.001305
# HT1080                                             0.575401
# NCIH2122                                           0.329036
# A2058                                              0.413817
# EN                                                -0.484726
#
#           KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC_TO_MGLUR5_CA2_APOPTOTIC_PATHWAY  \
# LS123                                              0.191074
# DANG                                              -0.205094
# NCIH211                                           -0.317287
# NCIH2172                                           0.117165
# OC314                                             -0.091089
# ...                                                     ...
# RCHACV                                             0.086332
# HT1080                                             0.255993
# NCIH2122                                           0.278010
# A2058                                              0.165448
# EN                                                -0.337824
#
#           KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC_TO_PERK_ATF4_SIGNALING_PATHWAY  \
# LS123                                             -0.299353
# DANG                                              -0.291670
# NCIH211                                           -0.474502
# NCIH2172                                           0.019126
# OC314                                             -0.019902
# ...                                                     ...
# RCHACV                                            -0.216905
# HT1080                                            -0.062307
# NCIH2122                                           0.030893
# A2058                                             -0.120842
# EN                                                 0.223845
#
#           KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC_TO_TRANSPORT_OF_CALCIUM  \
# LS123                                              0.189991
# DANG                                              -0.146956
# NCIH211                                           -0.408960
# NCIH2172                                           0.307145
# OC314                                             -0.016465
# ...                                                     ...
# RCHACV                                             0.298192
# HT1080                                             0.103742
# NCIH2122                                           0.282229
# A2058                                              0.159694
# EN                                                -0.361752
#
#           KEGG_MEDICUS_VARIANT_SCRAPIE_CONFORMATION_PRPSC_TO_VGCC_CA2_APOPTOTIC_PATHWAY  \
# LS123                                              0.350120
# DANG                                              -0.359000
# NCIH211                                            0.060526
# NCIH2172                                          -0.322797
# OC314                                              0.433051
# ...                                                     ...
# RCHACV                                            -0.315804
# HT1080                                            -0.066223
# NCIH2122                                           0.472902
# A2058                                             -0.039832
# EN                                                -0.349794
#
#           KEGG_MEDICUS_VARIANT_TEL_AML1_FUSION_TO_TRANSCRIPTIONAL_REPRESSION  \
# LS123                                              0.153698
# DANG                                               0.214869
# NCIH211                                            0.150719
# NCIH2172                                          -0.450869
# OC314                                             -0.422244
# ...                                                     ...
# RCHACV                                             0.226360
# HT1080                                            -0.008406
# NCIH2122                                           0.143874
# A2058                                              0.126936
# EN                                                -0.470223
#
#           KEGG_MEDICUS_VARIANT_TGFA_OVEREXPRESSION_TO_PI3K_SIGNALING_PATHWAY  \
# LS123                                              0.325649
# DANG                                               0.486002
# NCIH211                                           -0.418457
# NCIH2172                                          -0.194977
# OC314                                              0.240311
# ...                                                     ...
# RCHACV                                            -0.045004
# HT1080                                             0.539626
# NCIH2122                                          -0.381703
# A2058                                              0.204056
# EN                                                -0.529679
#
#           KEGG_MEDICUS_VARIANT_TMPRSS2_ERG_FUSION_TO_TRANSCRIPTIONAL_ACTIVATION  \
# LS123                                              0.427703
# DANG                                               0.280505
# NCIH211                                           -0.586841
# NCIH2172                                          -0.155385
# OC314                                             -0.078003
# ...                                                     ...
# RCHACV                                             0.065967
# HT1080                                             0.637610
# NCIH2122                                           0.407266
# A2058                                             -0.195133
# EN                                                -0.413580
#
#           KEGG_MEDICUS_VARIANT_TRK_FUSION_KINASE_TO_RAS_ERK_SIGNALING_PATHWAY
# LS123                                             -0.012462
# DANG                                               0.015323
# NCIH211                                            0.378458
# NCIH2172                                           0.059008
# OC314                                             -0.642325
# ...                                                     ...
# RCHACV                                             0.016109
# HT1080                                             0.132106
# NCIH2122                                          -0.447300
# A2058                                              0.052947
# EN                                                -0.024963
#
# [601 rows x 658 columns]

# %%
dataset = ModifiedMGATAFDataset(
    gdsc_df=gdsc_df,
    fingerprint_dict=fingerprint_dict,
    cell_feature_matrix=binary_feature_matrix,
    gsva_matrix=gsva_matrix,
    graph_dict=precomputed_graphs
)

# %%
sample = dataset[0]
graph, fingerprint, cell_feat, gsva_feat, label = sample

print("Graph:")
print(graph)
print("Graph node features shape:", graph.x.shape)
print("Graph edge_index shape:", graph.edge_index.shape)
print()

print("Fingerprint shape:", fingerprint.shape)
print("Cell line features shape:", cell_feat.shape)
print("GSVA features shape:", gsva_feat.shape)
print("Label (ln_IC50):", label)
# Out:
# Graph:
# Data(x=[26, 55], edge_index=[2, 60])
# Graph node features shape: torch.Size([26, 55])
# Graph edge_index shape: torch.Size([2, 60])
#
# Fingerprint shape: torch.Size([2048])
# Cell line features shape: torch.Size([735])
# GSVA features shape: torch.Size([658])
# Label (ln_IC50): tensor([0.3806])

# %%
from torch_geometric.data import Batch

def modified_mgataf_collate_fn(batch):
    graphs, fingerprints, ccl_feats, gsva_feats, labels = zip(*batch)

    # Batch graph objects using PyG
    graph_batch = Batch.from_data_list(graphs)

    # Stack other tensors
    fingerprint_batch = torch.stack(fingerprints)
    ccl_feat_batch = torch.stack(ccl_feats)
    gsva_feat_batch = torch.stack(gsva_feats)
    label_batch = torch.stack(labels)

    return graph_batch, fingerprint_batch, ccl_feat_batch, gsva_feat_batch, label_batch

# %% [markdown]
# # Model Build

# %% [markdown]
# ## Encoding

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch_geometric.nn import GATConv, global_add_pool

# %%
class DrugGraphEncoder(nn.Module):
    def __init__(self, in_dim, hidden_dim=64, out_dim=128, num_layers=3, heads=4):
        super().__init__()
        self.gats = nn.ModuleList()
        self.num_layers = num_layers
        self.att_proj = nn.Linear(hidden_dim, 1)

        self.gats.append(GATConv(in_dim, hidden_dim, heads=heads, concat=False))
        for _ in range(1, num_layers):
            self.gats.append(GATConv(hidden_dim, hidden_dim, heads=heads, concat=False))

    def forward(self, data):
        x, edge_index, batch = data.x, data.edge_index, data.batch
        layer_outputs = []

        for gat in self.gats:
            x = F.relu(gat(x, edge_index))
            pooled = global_add_pool(x, batch)
            layer_outputs.append(pooled)

        h = torch.stack(layer_outputs, dim=1)  # [B, L, D]
        attn_weights = F.softmax(self.att_proj(h).squeeze(-1), dim=1)  # [B, L]
        h_weighted = (h * attn_weights.unsqueeze(-1)).sum(dim=1)  # [B, D]
        return h_weighted

# %%
class FingerprintEncoder(nn.Module):
    def __init__(self, in_dim=2048, out_dim=128):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(1, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv1d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
        )

        # Dummy pass to infer output size
        with torch.no_grad():
            dummy = torch.zeros(1, 1, in_dim)
            conv_out = self.conv(dummy)
            conv_flat_dim = conv_out.view(1, -1).shape[1]

        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(conv_flat_dim, out_dim),
            nn.ReLU()
        )

    def forward(self, x):
        x = x.unsqueeze(1)
        x = self.conv(x)
        x = self.fc(x)
        return x

# %%
class CellLineEncoder(nn.Module):
    def __init__(self, in_dim=735, out_dim=128):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(1, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv1d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
        )

        # Dynamically infer flattened dimension
        with torch.no_grad():
            dummy = torch.zeros(1, 1, in_dim)
            conv_out = self.conv(dummy)
            flat_dim = conv_out.view(1, -1).shape[1]

        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(flat_dim, out_dim),
            nn.ReLU()
        )

    def forward(self, x):
        x = x.unsqueeze(1)  # [B, 1, 735]
        x = self.conv(x)
        x = self.fc(x)
        return x

# %%
class GSVAEncoder(nn.Module):
    def __init__(self, in_dim=658, out_dim=128):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv1d(1, 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv1d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
        )

        with torch.no_grad():
            dummy = torch.zeros(1, 1, in_dim)
            conv_out = self.conv(dummy)
            flat_dim = conv_out.view(1, -1).shape[1]

        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(flat_dim, out_dim),
            nn.ReLU()
        )

    def forward(self, x):
        x = x.unsqueeze(1)  # [B, 1, 658]
        x = self.conv(x)
        x = self.fc(x)
        return x

# %% [markdown]
# ## Adaptive Fusion

# %%
class AdaptiveFusion(nn.Module):
    def __init__(self, input_dim, hidden_dim):
        super().__init__()
        self.gate_layer = nn.Sequential(
            nn.Linear(input_dim * 2, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, input_dim),
            nn.Sigmoid()
        )

    def forward(self, x1, x2):
        # x1: drug + fp, x2: ccl
        concat = torch.cat([x1, x2], dim=1)
        gate = self.gate_layer(concat)

        fused = gate * x1 + (1 - gate) * x2
        return fused

# %% [markdown]
# ## Final Dense Layer

# %%
class IC50Predictor(nn.Module):
    def __init__(self, input_dim):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 1)
        )

    def forward(self, x):
        return self.fc(x)

# %% [markdown]
# ## Complete Model

# %%
class ModifiedMGATAFModel(nn.Module):
    def __init__(self, atom_feat_dim=55, fingerprint_dim=2048, ccl_dim=735, gsva_dim=658, hidden_dim=128):
        super().__init__()
        self.drug_encoder = DrugGraphEncoder(in_dim=atom_feat_dim, hidden_dim=hidden_dim)
        self.fp_encoder = FingerprintEncoder(in_dim=fingerprint_dim, out_dim=hidden_dim)

        self.ccl_encoder = CellLineEncoder(in_dim=ccl_dim, out_dim=hidden_dim)
        self.gsva_encoder = GSVAEncoder(in_dim=gsva_dim, out_dim=hidden_dim)
        
        self.drug_fusion = AdaptiveFusion(input_dim=hidden_dim, hidden_dim=hidden_dim)
        self.cellline_fusion = AdaptiveFusion(input_dim=hidden_dim, hidden_dim=hidden_dim)  # new!
        self.fusion = AdaptiveFusion(input_dim=hidden_dim, hidden_dim=hidden_dim)

        self.regressor = IC50Predictor(input_dim=hidden_dim)

    def forward(self, graph_data, fingerprint, ccl_feat, gsva_feat):
        # Drug branch
        drug_repr = self.drug_encoder(graph_data)
        fp_repr = self.fp_encoder(fingerprint)
        # drug_combined = drug_repr + fp_repr
        drug_combined = self.drug_fusion(drug_repr, fp_repr)

        # Cell line branch
        ccl_repr = self.ccl_encoder(ccl_feat)
        gsva_repr = self.gsva_encoder(gsva_feat)
        final_ccl_repr = self.cellline_fusion(ccl_repr, gsva_repr)

        # Final fusion
        fused = self.fusion(drug_combined, final_ccl_repr)

        return self.regressor(fused)

# %% [markdown]
# # Training

# %% [markdown]
# ### Data Split

# %%
from sklearn.model_selection import train_test_split

indices = list(range(len(dataset)))
train_idx, test_idx = train_test_split(indices, test_size=0.1, random_state=42)
train_idx, val_idx = train_test_split(train_idx, test_size=0.1, random_state=42)

from torch.utils.data import Subset
train_set = Subset(dataset, train_idx)
val_set = Subset(dataset, val_idx)
test_set = Subset(dataset, test_idx)

# %% [markdown]
# ### Creating DataLoaders

# %%
from torch_geometric.loader import DataLoader

train_loader = DataLoader(train_set, batch_size=64, shuffle=True, collate_fn=modified_mgataf_collate_fn)
val_loader = DataLoader(val_set, batch_size=64, shuffle=False, collate_fn=modified_mgataf_collate_fn)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False, collate_fn=modified_mgataf_collate_fn)

# %% [markdown]
# ### Training Loop

# %%
torch.backends.cudnn.benchmark = True

# %%
import torch
print("CUDA Available:", torch.cuda.is_available())
print("Device name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
# Out:
# CUDA Available: True
# Device name: NVIDIA RTX 6000 Ada Generation

# %%
from tqdm import tqdm
import torch.nn as nn
import torch.optim as optim

from sklearn.metrics import root_mean_squared_error
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import numpy as np

import os

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ModifiedMGATAFModel().to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
loss_fn = nn.MSELoss()
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5)

best_val_loss = float('inf')
patience_counter = 0
max_patience = 10
num_epochs = 100


# Trackers
train_rmse_list = []
val_rmse_list = []
val_pcc_list = []


# Paths
checkpoint_model_path = f"models/checkpoints/modified_mgataf_ablation/modified_mgataf_checkpoint_model_{ablation_study_id}.pt"
checkpoint_opt_path = f"models/checkpoints/modified_mgataf_ablation/mgataf_checkpoint_optim_{ablation_study_id}.pt"
checkpoint_meta_path = f"models/checkpoints/modified_mgataf_ablation/mgataf_checkpoint_meta_{ablation_study_id}.pt"

# Defaults
start_epoch = 0

# Resume
if os.path.exists(checkpoint_model_path) and os.path.exists(checkpoint_opt_path) and os.path.exists(checkpoint_meta_path):
    print("🔄 Resuming model...")
    model.load_state_dict(torch.load(checkpoint_model_path))

    # if os.path.exists(checkpoint_opt_path):
    optimizer.load_state_dict(torch.load(checkpoint_opt_path))

    # if os.path.exists(checkpoint_meta_path):
    meta = torch.load(checkpoint_meta_path)
    start_epoch = meta["epoch"] + 1
    best_val_loss = meta["best_val_loss"]
    patience_counter = meta["patience_counter"]

    print(f"✅ Resumed from epoch {start_epoch} | Best Val Loss: {best_val_loss:.4f}")


for epoch in range(start_epoch, num_epochs + 1):
    model.train()
    train_preds, train_labels = [], []

    loop = tqdm(train_loader, desc=f"Epoch {epoch+1}", leave=True)
    for batch_idx, (graph_data, fingerprint, ccl_feat, gsva_feat, label) in enumerate(loop):
        graph_data = graph_data.to(device)
        fingerprint = fingerprint.to(device)
        ccl_feat = ccl_feat.to(device)
        gsva_feat = gsva_feat.to(device)
        label = label.to(device)

        optimizer.zero_grad()
        output = model(graph_data, fingerprint, ccl_feat, gsva_feat)
        loss = loss_fn(output, label)
        loss.backward()
        optimizer.step()

        train_preds.append(output.detach().cpu().numpy())
        train_labels.append(label.cpu().numpy())
        
        # Every N batches, compute and show running metrics
        if (batch_idx + 1) % 100 == 0 or (batch_idx + 1) == len(train_loader):
            pred_flat = np.concatenate(train_preds).flatten()
            label_flat = np.concatenate(train_labels).flatten()
            rmse = root_mean_squared_error(label_flat, pred_flat)
            try:
                pcc = pearsonr(label_flat, pred_flat)[0]
            except:
                pcc = float('nan')

            loop.set_postfix(train_rmse=f"{rmse:.4f}", train_pcc=f"{pcc:.4f}")

    train_preds_flat = np.concatenate(train_preds).flatten()
    train_labels_flat = np.concatenate(train_labels).flatten()
    train_rmse = root_mean_squared_error(train_labels_flat, train_preds_flat)
    train_rmse_list.append(train_rmse)

    # Validation
    model.eval()
    val_preds, val_labels = [], []
    with torch.no_grad():
        for graph_data, fingerprint, ccl_feat, gsva_feat, label in val_loader:
            graph_data = graph_data.to(device)
            fingerprint = fingerprint.to(device)
            ccl_feat = ccl_feat.to(device)
            gsva_feat = gsva_feat.to(device)
            label = label.to(device)

            output = model(graph_data, fingerprint, ccl_feat, gsva_feat)
            val_preds.append(output.cpu().numpy())
            val_labels.append(label.cpu().numpy())

    val_preds_flat = np.concatenate(val_preds).flatten()
    val_labels_flat = np.concatenate(val_labels).flatten()
    val_rmse = root_mean_squared_error(val_labels_flat, val_preds_flat)
    val_pcc = pearsonr(val_preds_flat, val_labels_flat)[0]

    val_rmse_list.append(val_rmse)
    val_pcc_list.append(val_pcc)

    scheduler.step(val_rmse)

    print(f"[Epoch {epoch+1}] Train RMSE: {train_rmse:.4f} | Val RMSE: {val_rmse:.4f} | Val PCC: {val_pcc:.4f}")

    if val_rmse < best_val_loss:
        best_val_loss = val_rmse
        patience_counter = 0
        torch.save(model.state_dict(), f"models/modified_mgataf_type{ablation_study_id}_best_model.pt")
        print(f"[Saved Best Model] | Val RMSE: {val_rmse:.4f} | Val PCC: {val_pcc:.4f}")
    else:
        patience_counter += 1
        if patience_counter >= max_patience:
            print("Early stopping triggered.")
            break

    if (epoch % 5) == 0:
        torch.save(model.state_dict(), checkpoint_model_path)
        torch.save(optimizer.state_dict(), checkpoint_opt_path)
        torch.save({
            "epoch": epoch,
            "best_val_loss": best_val_loss,
            "patience_counter": patience_counter
        }, checkpoint_meta_path)
        print(f"[Checkpointed Model and State] | Val RMSE: {val_rmse:.4f} | Val PCC: {val_pcc:.4f}")
# Out:
# Epoch 1: 100%|██████████| 1584/1584 [00:57<00:00, 27.54it/s, train_pcc=0.7823, train_rmse=0.0439]
# [Epoch 1] Train RMSE: 0.0439 | Val RMSE: 0.0308 | Val PCC: 0.8940
# [Saved Best Model] | Val RMSE: 0.0308 | Val PCC: 0.8940
# [Checkpointed Model and State] | Val RMSE: 0.0308 | Val PCC: 0.8940
# Epoch 2: 100%|██████████| 1584/1584 [00:55<00:00, 28.40it/s, train_pcc=0.8859, train_rmse=0.0319]
# [Epoch 2] Train RMSE: 0.0319 | Val RMSE: 0.0298 | Val PCC: 0.9009
# [Saved Best Model] | Val RMSE: 0.0298 | Val PCC: 0.9009
# Epoch 3: 100%|██████████| 1584/1584 [00:54<00:00, 28.93it/s, train_pcc=0.8981, train_rmse=0.0302]
# [Epoch 3] Train RMSE: 0.0302 | Val RMSE: 0.0295 | Val PCC: 0.9083
# [Saved Best Model] | Val RMSE: 0.0295 | Val PCC: 0.9083
# Epoch 4: 100%|██████████| 1584/1584 [00:55<00:00, 28.62it/s, train_pcc=0.9062, train_rmse=0.0291]
# [Epoch 4] Train RMSE: 0.0291 | Val RMSE: 0.0284 | Val PCC: 0.9113
# [Saved Best Model] | Val RMSE: 0.0284 | Val PCC: 0.9113
# Epoch 5: 100%|██████████| 1584/1584 [00:56<00:00, 27.91it/s, train_pcc=0.9130, train_rmse=0.0281]
# [Epoch 5] Train RMSE: 0.0281 | Val RMSE: 0.0282 | Val PCC: 0.9188
# [Saved Best Model] | Val RMSE: 0.0282 | Val PCC: 0.9188
# Epoch 6: 100%|██████████| 1584/1584 [00:56<00:00, 28.14it/s, train_pcc=0.9177, train_rmse=0.0273]
# [Epoch 6] Train RMSE: 0.0273 | Val RMSE: 0.0269 | Val PCC: 0.9212
# [Saved Best Model] | Val RMSE: 0.0269 | Val PCC: 0.9212
# [Epoch 29] Train RMSE: 0.0204 | Val RMSE: 0.0245 | Val PCC: 0.9352
# Epoch 30: 100%|██████████| 1584/1584 [00:50<00:00, 31.10it/s, train_pcc=0.9597, train_rmse=0.0193]
# [Epoch 30] Train RMSE: 0.0193 | Val RMSE: 0.0241 | Val PCC: 0.9363
# [Saved Best Model] | Val RMSE: 0.0241 | Val PCC: 0.9363
# Epoch 31: 100%|██████████| 1584/1584 [00:52<00:00, 29.98it/s, train_pcc=0.9606, train_rmse=0.0191]
# [Epoch 31] Train RMSE: 0.0191 | Val RMSE: 0.0244 | Val PCC: 0.9353
# [Checkpointed Model and State] | Val RMSE: 0.0244 | Val PCC: 0.9353
# Epoch 32: 100%|██████████| 1584/1584 [00:51<00:00, 30.77it/s, train_pcc=0.9610, train_rmse=0.0190]
# [Epoch 32] Train RMSE: 0.0190 | Val RMSE: 0.0244 | Val PCC: 0.9349
# Epoch 33: 100%|██████████| 1584/1584 [00:52<00:00, 30.40it/s, train_pcc=0.9615, train_rmse=0.0189]
# [Epoch 33] Train RMSE: 0.0189 | Val RMSE: 0.0244 | Val PCC: 0.9351
# Epoch 34: 100%|██████████| 1584/1584 [00:53<00:00, 29.60it/s, train_pcc=0.9619, train_rmse=0.0188]
# [Epoch 34] Train RMSE: 0.0188 | Val RMSE: 0.0245 | Val PCC: 0.9345
# Epoch 35: 100%|██████████| 1584/1584 [00:48<00:00, 32.46it/s, train_pcc=0.9622, train_rmse=0.0187]
# [Epoch 35] Train RMSE: 0.0187 | Val RMSE: 0.0247 | Val PCC: 0.9339
# Epoch 36: 100%|██████████| 1584/1584 [00:52<00:00, 30.04it/s, train_pcc=0.9626, train_rmse=0.0186]
# [Epoch 36] Train RMSE: 0.0186 | Val RMSE: 0.0246 | Val PCC: 0.9342
# [Checkpointed Model and State] | Val RMSE: 0.0246 | Val PCC: 0.9342
# Epoch 37: 100%|██████████| 1584/1584 [00:49<00:00, 32.07it/s, train_pcc=0.9650, train_rmse=0.0180]
# [Epoch 37] Train RMSE: 0.0180 | Val RMSE: 0.0246 | Val PCC: 0.9343
# Epoch 38: 100%|██████████| 1584/1584 [00:49<00:00, 32.31it/s, train_pcc=0.9654, train_rmse=0.0179]
# [Epoch 38] Train RMSE: 0.0179 | Val RMSE: 0.0247 | Val PCC: 0.9342
# Epoch 39: 100%|██████████| 1584/1584 [00:50<00:00, 31.52it/s, train_pcc=0.9656, train_rmse=0.0179]
# [Epoch 39] Train RMSE: 0.0179 | Val RMSE: 0.0246 | Val PCC: 0.9340
# Epoch 40: 100%|██████████| 1584/1584 [00:53<00:00, 29.69it/s, train_pcc=0.9658, train_rmse=0.0178]
# [Epoch 40] Train RMSE: 0.0178 | Val RMSE: 0.0245 | Val PCC: 0.9346
# Early stopping triggered.

# %% [markdown]
# Split the dataset on DRUGS to ensure there are no dataleaks!!!

# %%
# Plot RMSE vs Epoch
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(train_rmse_list)+1), train_rmse_list, label="Train RMSE")
plt.plot(range(1, len(val_rmse_list)+1), val_rmse_list, label="Validation RMSE")
plt.xlabel("Epoch")
plt.ylabel("RMSE")
plt.title("RMSE vs Epoch")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Testing and Evaluation

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Re-initialize model
model = ModifiedMGATAFModel().to(device)

# Load best saved weights
model.load_state_dict(torch.load(f"models/modified_mgataf_type{ablation_study_id}_best_model.pt"))
model.eval()
# Out:
# ModifiedMGATAFModel(
#   (drug_encoder): DrugGraphEncoder(
#     (gats): ModuleList(
#       (0): GATConv(55, 128, heads=4)
#       (1-2): 2 x GATConv(128, 128, heads=4)
#     )
#     (att_proj): Linear(in_features=128, out_features=1, bias=True)
#   )
#   (fp_encoder): FingerprintEncoder(
#     (conv): Sequential(
#       (0): Conv1d(1, 32, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#       (2): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#       (3): ReLU()
#     )
#     (fc): Sequential(
#       (0): Flatten(start_dim=1, end_dim=-1)
#       (1): Linear(in_features=16256, out_features=128, bias=True)
#       (2): ReLU()
#     )
#   )
#   (ccl_encoder): CellLineEncoder(
#     (conv): Sequential(
#       (0): Conv1d(1, 32, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#       (2): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#       (3): ReLU()
#     )
#     (fc): Sequential(
#       (0): Flatten(start_dim=1, end_dim=-1)
#       (1): Linear(in_features=5760, out_features=128, bias=True)
#       (2): ReLU()
#     )
#   )
#   (gsva_encoder): GSVAEncoder(
#     (conv): Sequential(
#       (0): Conv1d(1, 32, kernel_size=(8,), stride=(4,))
#       (1): ReLU()
#       (2): Conv1d(32, 64, kernel_size=(4,), stride=(2,))
#       (3): ReLU()
#     )
#     (fc): Sequential(
#       (0): Flatten(start_dim=1, end_dim=-1)
#       (1): Linear(in_features=5120, out_features=128, bias=True)
#       (2): ReLU()
#     )
#   )
#   (drug_fusion): AdaptiveFusion(
#     (gate_layer): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): Sigmoid()
#     )
#   )
#   (cellline_fusion): AdaptiveFusion(
#     (gate_layer): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): Sigmoid()
#     )
#   )
#   (fusion): AdaptiveFusion(
#     (gate_layer): Sequential(
#       (0): Linear(in_features=256, out_features=128, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=128, out_features=128, bias=True)
#       (3): Sigmoid()
#     )
#   )
#   (regressor): IC50Predictor(
#     (fc): Sequential(
#       (0): Linear(in_features=128, out_features=64, bias=True)
#       (1): ReLU()
#       (2): Linear(in_features=64, out_features=1, bias=True)
#     )
#   )
# )

# %%
from sklearn.metrics import root_mean_squared_error
from scipy.stats import pearsonr
import matplotlib.pyplot as plt
import numpy as np

all_preds = []
all_labels = []

with torch.no_grad():
    for graph_data, fingerprint, ccl_feat, gsva_feat, label in test_loader:
        graph_data = graph_data.to(device)
        fingerprint = fingerprint.to(device)
        ccl_feat = ccl_feat.to(device)
        gsva_feat = gsva_feat.to(device)
        label = label.to(device)

        preds = model(graph_data, fingerprint, ccl_feat, gsva_feat)
        all_preds.append(preds.cpu().numpy())
        all_labels.append(label.cpu().numpy())

# Flatten predictions and labels
y_pred = np.concatenate(all_preds).flatten()
y_true = np.concatenate(all_labels).flatten()

# Compute metrics
test_rmse = root_mean_squared_error(y_true, y_pred)
test_pcc = pearsonr(y_true, y_pred)[0]

print(f"✅ Test RMSE: {test_rmse:.4f}")
print(f"✅ Test PCC:  {test_pcc:.4f}")
# Out:
# ✅ Test RMSE: 0.0248
# ✅ Test PCC:  0.9319

# %%
plt.figure(figsize=(6, 6))
plt.scatter(y_true, y_pred, alpha=0.5, edgecolors='k')
plt.plot([min(y_true), max(y_true)], [min(y_true), max(y_true)], 'r--')
plt.xlabel("True ln(IC50)")
plt.ylabel("Predicted ln(IC50)")
plt.title("Predicted vs True ln(IC50)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
def print_parameter_breakdown(model):
    total = 0
    print("\nTrainable Parameters by Module:\n")
    for name, param in model.named_parameters():
        if param.requires_grad:
            count = param.numel()
            print(f"{name:<50} {count:>10}")
            total += count
    print(f"\nTotal Trainable Parameters: {total:,}")

print_parameter_breakdown(model)
# Out:
# Trainable Parameters by Module:
#
# drug_encoder.gats.0.att_src                               512
# drug_encoder.gats.0.att_dst                               512
# drug_encoder.gats.0.bias                                  128
# drug_encoder.gats.0.lin.weight                          28160
# drug_encoder.gats.1.att_src                               512
# drug_encoder.gats.1.att_dst                               512
# drug_encoder.gats.1.bias                                  128
# drug_encoder.gats.1.lin.weight                          65536
# drug_encoder.gats.2.att_src                               512
# drug_encoder.gats.2.att_dst                               512
# drug_encoder.gats.2.bias                                  128
# drug_encoder.gats.2.lin.weight                          65536
# drug_encoder.att_proj.weight                              128
# drug_encoder.att_proj.bias                                  1
# fp_encoder.conv.0.weight                                  256
# fp_encoder.conv.0.bias                                     32
# fp_encoder.conv.2.weight                                 8192
# fp_encoder.conv.2.bias                                     64
# fp_encoder.fc.1.weight                                2080768
# fp_encoder.fc.1.bias                                      128
# ccl_encoder.conv.0.weight                                 256
# ccl_encoder.conv.0.bias                                    32
# ccl_encoder.conv.2.weight                                8192
# ccl_encoder.conv.2.bias                                    64
# ccl_encoder.fc.1.weight                                737280
# ccl_encoder.fc.1.bias                                     128
# gsva_encoder.conv.0.weight                                256
# gsva_encoder.conv.0.bias                                   32
# gsva_encoder.conv.2.weight                               8192
# gsva_encoder.conv.2.bias                                   64
# gsva_encoder.fc.1.weight                               655360
# gsva_encoder.fc.1.bias                                    128
# drug_fusion.gate_layer.0.weight                         32768
# drug_fusion.gate_layer.0.bias                             128
# drug_fusion.gate_layer.2.weight                         16384
# drug_fusion.gate_layer.2.bias                             128
# cellline_fusion.gate_layer.0.weight                     32768
# cellline_fusion.gate_layer.0.bias                         128
# cellline_fusion.gate_layer.2.weight                     16384
# cellline_fusion.gate_layer.2.bias                         128
# fusion.gate_layer.0.weight                              32768
# fusion.gate_layer.0.bias                                  128
# fusion.gate_layer.2.weight                              16384
# fusion.gate_layer.2.bias                                  128
# regressor.fc.0.weight                                    8192
# regressor.fc.0.bias                                        64
# regressor.fc.2.weight                                      64
# regressor.fc.2.bias                                         1
#
# Total Trainable Parameters: 3,818,786
